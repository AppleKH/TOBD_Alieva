# %% [markdown]
# # Pandas

# %% [markdown]
# Материалы:
# * Макрушин С.В. "Лекция 2: Библиотека Pandas"
# * https://pandas.pydata.org/docs/user_guide/index.html#
# * https://pandas.pydata.org/docs/reference/index.html
# * Уэс Маккини. Python и анализ данных

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Задачи для совместного разбора

# %% [markdown]
# 1. Загрузите данные из файла `sp500hst.txt` и обозначьте столбцы в соответствии с содержимым: `"date", "ticker", "open", "high", "low", "close", "volume"`.

# %%
df = pd.read_csv('sp500hst.txt', names=["date", "ticker", "open", "high", "low", "close", "volume"])
df.head()
# Out:
#        date ticker   open     high     low  close  volume
# 0  20090821      A  25.60  25.6100  25.220  25.55   34758
# 1  20090824      A  25.64  25.7400  25.330  25.50   22247
# 2  20090825      A  25.50  25.7000  25.225  25.34   30891
# 3  20090826      A  25.32  25.6425  25.145  25.48   33334
# 4  20090827      A  25.50  25.5700  25.230  25.54   70176

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
df.iloc[:,2:6].mean()
# Out:
# open     42.595458
# high     43.102243
# low      42.054464
# close    42.601865
# dtype: float64

# %% [markdown]
# 3. Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
pd.to_datetime(df['date'], format='%Y%m%d').dt.day.head()
# Out:
# 0    21
# 1    24
# 2    25
# 3    26
# 4    27
# Name: date, dtype: int64

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
df.groupby('ticker')['volume'].sum()
# Out:
# ticker
# A        8609336
# AA      81898998
# AAPL    52261170
# ABC      9006756
# ABT     18975870
#           ...
# XTO     21297931
# YHOO    56837171
# YUM     10971538
# ZION    15551119
# ZMH      4938916
# Name: volume, Length: 524, dtype: int64

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла `sp_data2.csv` . В случае нехватки данных об именах тикеров корректно обработать их.

# %%
headers = ["ticker", "company", "percent"]
sp = pd.read_csv("sp_data2.csv", sep=";", names=headers)
print(sp)
sp.head()
# Out:
#     ticker          company percent
# 0     AAPL            Apple    3.6%
# 1     AMZN       Amazon.com    3.2%
# 2    GOOGL         Alphabet    3.1%
# 3     GOOG         Alphabet    3.1%
# 4     MSFT        Microsoft    3.0%
# ..     ...              ...     ...
# 500    SCG            SCANA    0.0%
# 501    AIZ         Assurant    0.0%
# 502    AYI    Acuity Brands    0.0%
# 503    HRB        H&R Block    0.0%
# 504    RRC  Range Resources    0.0%
#
# [505 rows x 3 columns]
#   ticker     company percent
# 0   AAPL       Apple    3.6%
# 1   AMZN  Amazon.com    3.2%
# 2  GOOGL    Alphabet    3.1%
# 3   GOOG    Alphabet    3.1%
# 4   MSFT   Microsoft    3.0%

# %%
pd.merge(df, sp, how='inner', left_on="ticker", right_on="ticker")
# Out:
#            date ticker   open     high     low  close  volume  \
# 0      20090821      A  25.60  25.6100  25.220  25.55   34758
# 1      20090824      A  25.64  25.7400  25.330  25.50   22247
# 2      20090825      A  25.50  25.7000  25.225  25.34   30891
# 3      20090826      A  25.32  25.6425  25.145  25.48   33334
# 4      20090827      A  25.50  25.5700  25.230  25.54   70176
# ...         ...    ...    ...      ...     ...    ...     ...
# 82167  20100813   ZION  20.17  20.4300  19.840  19.89   25193
# 82168  20100816   ZION  19.81  19.9600  19.600  19.95   25914
# 82169  20100817   ZION  20.07  20.4700  19.830  20.31   31717
# 82170  20100819   ZION  19.83  20.0000  19.130  19.35   45935
# 82171  20100820   ZION  19.15  19.2700  18.810  19.14   37225
#
#                     company percent
# 0      Agilent Technologies    0.1%
# 1      Agilent Technologies    0.1%
# 2      Agilent Technologies    0.1%
# 3      Agilent Technologies    0.1%
# 4      Agilent Technologies    0.1%
# ...                     ...     ...
# 82167         Zions Bancorp    0.0%
# 82168         Zions Bancorp    0.0%
# 82169         Zions Bancorp    0.0%
# 82170         Zions Bancorp    0.0%
# 82171         Zions Bancorp    0.0%
#
# [82172 rows x 9 columns]

# %% [markdown]
# ## Лабораторная работа №2

# %% [markdown]
# ### Базовые операции с `DataFrame`

# %% [markdown]
# 1.1 В файлах `recipes_sample.csv` и `reviews_sample.csv` находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде `pd.DataFrame` с названиями `recipes` и `reviews`. Обратите внимание на корректное считывание столбца с индексами в таблице `reviews` (безымянный столбец).

# %%
recipes = pd.read_csv("recipes_sample.csv", sep=",", parse_dates=['submitted'])
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [30000 rows x 8 columns]

# %%
reviews = pd.read_csv("reviews_sample.csv", sep=",", parse_dates=["date"])
reviews
# Out:
#         Unnamed: 0     user_id  recipe_id       date  rating  \
# 0           370476       21752      57993 2003-05-01       5
# 1           624300      431813     142201 2007-09-16       5
# 2           187037      400708     252013 2008-01-10       4
# 3           706134  2001852463     404716 2017-12-11       5
# 4           312179       95810     129396 2008-03-14       5
# ...            ...         ...        ...        ...     ...
# 126691     1013457     1270706     335534 2009-05-17       4
# 126692      158736     2282344       8701 2012-06-03       0
# 126693     1059834      689540     222001 2008-04-08       5
# 126694      453285  2000242659     354979 2015-06-02       5
# 126695      691207      463435     415599 2010-09-30       5
#
#                                                    review
# 0       Last week whole sides of frozen salmon fillet ...
# 1       So simple and so tasty!  I used a yellow capsi...
# 2       Very nice breakfast HH, easy to make and yummy...
# 3       These are a favorite for the holidays and so e...
# 4       Excellent soup!  The tomato flavor is just gre...
# ...                                                   ...
# 126691  This recipe was great! I made it last night. I...
# 126692  This recipe is outstanding. I followed the rec...
# 126693  Well, we were not a crowd but it was a fabulou...
# 126694  I have been a steak eater and dedicated BBQ gr...
# 126695  Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 6 columns]

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
# * количество точек данных (строк);
# * количество столбцов;
# * тип данных каждого столбца.

# %%
print(f"recipes: {recipes.shape[0]} {len(recipes.columns)}")
recipes.dtypes
# Out:
# recipes: 30000 8
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %%
print(f"reviews: {reviews.shape[0]} {len(reviews.columns)}")
reviews.dtypes
# Out:
# reviews: 126696 6
# Unnamed: 0             int64
# user_id                int64
# recipe_id              int64
# date          datetime64[ns]
# rating                 int64
# review                object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
all_count = recipes.shape[0]
without_none_count = recipes.dropna().shape[0]
none_count = all_count - without_none_count
print(f"{all_count}\n{without_none_count}\n{none_count}")

str(round(none_count*100/all_count,2))+"%"
# Out:
# 30000
# 12946
# 17054
# '56.85%'

# %%
recipes.isnull().sum()
# Out:
# name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64

# %%
all_count = reviews.shape[0]
without_none_count = reviews.dropna().shape[0]
none_count = all_count - without_none_count
print(f"{all_count}\n{without_none_count}\n{none_count}")

str(round(none_count*100/all_count,2))+"%"
# Out:
# 126696
# 126679
# 17
# '0.01%'

# %%
reviews.isnull().sum()
# Out:
# Unnamed: 0     0
# user_id        0
# recipe_id      0
# date           0
# rating         0
# review        17
# dtype: int64

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
for column in ("minutes","n_ingredients","n_steps"):
    print(f"{column} {round(recipes[column].mean(),2)}")
# Out:
# minutes 123.36
# n_ingredients 9.01
# n_steps 9.81

# %%
for column in ["rating"]:
    print(f"{column} {round(reviews[column].mean(),2)}")
# Out:
# rating 4.41

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
result = recipes["name"].sample(10)
print(type(result))
result
# Out:
# <class 'pandas.core.series.Series'>
# 22428                                 reggae wraps
# 19473                       oriental cabbage salad
# 3352             blue ribbon peanut butter cookies
# 14013        honey mustard green beans vinaigrette
# 28092                           tuna and corn bake
# 27520            the ultimate crock pot pork roast
# 6711                chocolate peanut butter plunge
# 10366    egg white omlet with vegetable and cheese
# 4396                             cajun gingerbread
# 17590                       microwave egg frittata
# Name: name, dtype: object

# %% [markdown]
# 1.6 Измените индекс в таблице `reviews`, пронумеровав строки, начиная с нуля.

# %%
reviews.rename(columns={'Unnamed: 0': 'index'}, inplace=True)
reviews = reviews.set_index('index')
reviews
# Out:
#             user_id  recipe_id       date  rating  \
# index
# 370476        21752      57993 2003-05-01       5
# 624300       431813     142201 2007-09-16       5
# 187037       400708     252013 2008-01-10       4
# 706134   2001852463     404716 2017-12-11       5
# 312179        95810     129396 2008-03-14       5
# ...             ...        ...        ...     ...
# 1013457     1270706     335534 2009-05-17       4
# 158736      2282344       8701 2012-06-03       0
# 1059834      689540     222001 2008-04-08       5
# 453285   2000242659     354979 2015-06-02       5
# 691207       463435     415599 2010-09-30       5
#
#                                                     review
# index
# 370476   Last week whole sides of frozen salmon fillet ...
# 624300   So simple and so tasty!  I used a yellow capsi...
# 187037   Very nice breakfast HH, easy to make and yummy...
# 706134   These are a favorite for the holidays and so e...
# 312179   Excellent soup!  The tomato flavor is just gre...
# ...                                                    ...
# 1013457  This recipe was great! I made it last night. I...
# 158736   This recipe is outstanding. I followed the rec...
# 1059834  Well, we were not a crowd but it was a fabulou...
# 453285   I have been a steak eater and dedicated BBQ gr...
# 691207   Wonderful and simple to prepare seasoning blen...
#
# [126696 rows x 5 columns]

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
condition = (recipes['minutes'] < 21) & (recipes['n_ingredients'] < 6)
recipes.loc[condition]
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id  submitted  n_steps  \
# 28             213909 2008-05-06     11.0
# 60             213909 2008-05-16      NaN
# 90              58104 2004-09-29      4.0
# 91              47892 2008-02-13      NaN
# 94               4470 2001-09-03      NaN
# ...               ...        ...      ...
# 29873          724218 2008-05-27      9.0
# 29874           24386 2003-10-29      8.0
# 29905          305531 2007-09-29      4.0
# 29980          305531 2008-08-20      3.0
# 29983          152500 2006-03-31      6.0
#
#                                              description  n_ingredients
# 28     this is a wonderful quick bread to make as an ...            5.0
# 60     this recipe is so simple and the flavors are s...            5.0
# 90     pineapple mimosa was changed to hawaiian sunri...            3.0
# 91     "mmmm, i love bananas!" a --tasty dish-- origi...            4.0
# 94     this is a real short cut for cooks in a hurry....            2.0
# ...                                                  ...            ...
# 29873  i haven't tried this yet, but i am going to so...            5.0
# 29874  a fun thing for kids to do. may want to use mi...            3.0
# 29905  from betty crocker fresh spring recipes. i lik...            5.0
# 29980                                  simple and yummy!            3.0
# 29983  this dish is from tim malzer, a german chef wh...            5.0
#
# [2019 rows x 8 columns]

# %% [markdown]
# ### Работа с датами в `pandas`

# %% [markdown]
# 2.1 Преобразуйте столбец `submitted` из таблицы `recipes` в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes.dtypes
# Out:
# name                      object
# id                         int64
# minutes                    int64
# contributor_id             int64
# submitted         datetime64[ns]
# n_steps                  float64
# description               object
# n_ingredients            float64
# dtype: object

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
koshkas = recipes['submitted'].dt.year < 2011
recipes.loc[koshkas]
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29993                     zuni caf zucchini pickles  316950     2895
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29993           62264 2008-07-31      NaN
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29993  refrigerator pickles for some of the zucchini ...            8.0
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
# [27661 rows x 8 columns]

# %% [markdown]
# ### Работа со строковыми данными в `pandas`

# %% [markdown]
# 3.1  Добавьте в таблицу `recipes` столбец `description_length`, в котором хранится длина описания рецепта из столбца `description`.

# %%
description_length = recipes["description"].str.len()
recipes["description_length"] = description_length
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        description_length
# 0                   330.0
# 1                   255.0
# 2                    39.0
# 3                   154.0
# 4                   587.0
# ...                   ...
# 29995               484.0
# 29996               286.0
# 29997               311.0
# 29998               648.0
# 29999               125.0
#
# [30000 rows x 9 columns]

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице `recipes` таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
recipes["name"] = recipes["name"].str.capitalize()
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        description_length
# 0                   330.0
# 1                   255.0
# 2                    39.0
# 3                   154.0
# 4                   587.0
# ...                   ...
# 29995               484.0
# 29996               286.0
# 29997               311.0
# 29998               648.0
# 29999               125.0
#
# [30000 rows x 9 columns]

# %% [markdown]
# 3.3 Добавьте в таблицу `recipes` столбец `name_word_count`, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
recipes["name_word_count"] = recipes["name"].str.split().apply(len)
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        description_length  name_word_count
# 0                   330.0                8
# 1                   255.0                5
# 2                    39.0                7
# 3                   154.0                3
# 4                   587.0                8
# ...                   ...              ...
# 29995               484.0                8
# 29996               286.0                4
# 29997               311.0                5
# 29998               648.0                2
# 29999               125.0                7
#
# [30000 rows x 10 columns]

# %% [markdown]
# ### Группировки таблиц `pd.DataFrame`

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (`contributor_id`). Какой участник добавил максимальное кол-во рецептов?

# %%
n_by_state = recipes.groupby("contributor_id")["id"].count()
n_by_state
# Out:
# contributor_id
# 1530            5
# 1533          186
# 1534           50
# 1535           40
# 1538            8
#              ...
# 2001968497      2
# 2002059754      1
# 2002234079      1
# 2002234259      1
# 2002247884      1
# Name: id, Length: 8404, dtype: int64

# %%
recipes.loc[recipes['contributor_id'] == 1530]
# Out:
#                             name    id  minutes  contributor_id  submitted  \
# 2429     Basil parmesan biscuits   975       27            1530 1999-08-14
# 4627    Caramel apple milkshakes   128       25            1530 1999-09-12
# 6778   Chocolate tapioca pudding   224       50            1530 1999-08-14
# 8906             Cucumber relish   671       40            1530 1999-09-10
# 26182         Stuffed mozzarella  1155       10            1530 1999-08-28
#
#        n_steps                                 description  n_ingredients  \
# 2429       NaN  perfect with pasta or other italian dishes           10.0
# 4627       4.0                                         NaN            5.0
# 6778       NaN                                      yummy!            NaN
# 8906       NaN                                         NaN           10.0
# 26182      4.0                                         NaN            NaN
#
#        description_length  name_word_count
# 2429                 42.0                3
# 4627                  NaN                3
# 6778                  6.0                3
# 8906                  NaN                2
# 26182                 NaN                2

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
n_by_state = reviews.groupby("recipe_id")["rating"].mean()
n_by_state
# Out:
# recipe_id
# 48        1.000000
# 55        4.750000
# 66        4.944444
# 91        4.750000
# 94        5.000000
#             ...
# 536547    5.000000
# 536610    0.000000
# 536728    4.000000
# 536729    4.750000
# 536747    0.000000
# Name: rating, Length: 28100, dtype: float64

# %%
reviews.loc[reviews["recipe_id"] == 55]
# Out:
#         user_id  recipe_id       date  rating  \
# index
# 462145   165567         55 2006-03-31       5
# 462147   851190         55 2010-05-23       5
# 462144    53959         55 2006-01-12       4
# 462146  1060485         55 2009-04-07       5
#
#                                                    review
# index
# 462145  I LOVED this recipe! I was looking for a guaca...
# 462147  I used Italian plum tomatoes for this as they ...
# 462144  I liked it. I was surprised since it didn't ha...
# 462146  loved this! my family ate it all up! will deff...

# %% [markdown]
# 4.3 Посчитайте количество рецептов с разбивкой по годам создания.

# %%
n_by_state = recipes.groupby(recipes["submitted"].dt.year)["name"].count()
n_by_state
# Out:
# submitted
# 1999     275
# 2000     104
# 2001     589
# 2002    2644
# 2003    2334
# 2004    2153
# 2005    3130
# 2006    3473
# 2007    4429
# 2008    4029
# 2009    2963
# 2010    1538
# 2011     922
# 2012     659
# 2013     490
# 2014     139
# 2015      42
# 2016      24
# 2017      39
# 2018      24
# Name: name, dtype: int64

# %%
recipes[recipes["submitted"].dt.year == 2018]
# Out:
#                                                     name      id  minutes  \
# 4932                                 Cauliflower ceviche  536547       45
# 5200                     Cheesesteak stuffed onion rings  535783       60
# 8442                        Creole watermelon feta salad  536729       10
# 9812            Easy bagel dogs weight watchers friendly  535120       95
# 10978                                       Filet mignon  535584      130
# 11614                                  Fruit loop treats  535104       15
# 12124                              Gluten free  vegemite  536728        2
# 12300                                   Gotham rib steak  536098      142
# 13294               Hamburger potpie with homemade crust  536360      160
# 13380                    Hawaiian cheesecake fruit salad  535713       15
# 13397  Hawaiian shrimp truck special  garlic lemon bu...  536051      165
# 14525                                Instant pot goulash  534855       75
# 15938                                 Lemon pom pom cake  536747      210
# 17559                   Mexican style pickled vegetables  535650      210
# 17803                      Miracle home made puff pastry  536610       35
# 20780                            Pineapple cannoli cones  536473       20
# 23035                         Royal crown strawberry pie  535691       85
# 23312                                   Samoa sheet cake  535312       40
# 24477            Slow cooker cheesy bacon ranch potatoes  536212      260
# 26786                           Sweet tea baby back ribs  535269     1560
# 27370           The best ground beef tacos on the planet  535555       55
# 28879                                 Vietnamese chicken  535389       50
# 29220                       White bean and chicken chili  534786       50
# 29400                                       Widow s soup  536066       50
#
#        contributor_id  submitted  n_steps  \
# 4932       2002234079 2018-07-30     15.0
# 5200            33186 2018-05-10     10.0
# 8442          1052873 2018-08-11      4.0
# 9812           700213 2018-02-07     22.0
# 10978           33186 2018-04-11      NaN
# 11614      2001968497 2018-02-06      NaN
# 12124         1052873 2018-08-11      NaN
# 12300           33186 2018-06-26     13.0
# 13294      1801884905 2018-07-17     73.0
# 13380          219942 2018-04-27     22.0
# 13397          219942 2018-06-21     13.0
# 14525          225096 2018-01-08     36.0
# 15938      2002247884 2018-08-15     51.0
# 17559      2001968497 2018-04-19      NaN
# 17803      2002234259 2018-07-31     17.0
# 20780           33186 2018-07-25     16.0
# 23035           33186 2018-04-23     35.0
# 23312           33186 2018-03-07     15.0
# 24477          400708 2018-07-08      NaN
# 26786           33186 2018-03-05      NaN
# 27370          520605 2018-04-09      NaN
# 28879      2002059754 2018-03-20     10.0
# 29220      2001896867 2018-01-02      NaN
# 29400         1052873 2018-06-25      NaN
#
#                                              description  n_ingredients  \
# 4932   a healthy ceviche - a perfect appetizer for pa...            8.0
# 5200   surprise your family and friends with an onion...           11.0
# 8442   spicy watermelon salad. from tony chachere's s...            NaN
# 9812   this easy recipe is perfect if you’re watching...            NaN
# 10978  courtesy of chef kristen nguyen. must use high...           13.0
# 11614  fruity, slightly elevated, ridiculously easy a...            NaN
# 12124                   gluten free vegemite-like stuff.            3.0
# 12300        recipe courtesy of old homestead steakhouse            4.0
# 13294  the flaky, buttery crust is only the beginning...            NaN
# 13380  heavenly rich and fruity, a great summer fruit...           10.0
# 13397  caramelized garlic and lemon with a little spi...            9.0
# 14525  i have the 6 qt ultra and this is a full pot r...            NaN
# 15938  by far one of my most joyous cake creations, t...           20.0
# 17559  spicy chiles and sweet carrots make these pick...           13.0
# 17803  puff pastry that you can make in minutes? at h...            NaN
# 20780  folded pineapple puree throughout the cannoli ...           12.0
# 23035  crown-shaped pie with sweet and tangy strawber...           15.0
# 23312     all the flavors of a cookie baked into a cake.            NaN
# 24477  cheesy bacon ranch potatoes.  slow cooked all ...            NaN
# 26786       courtesy of deborah van treece, twisted soul           14.0
# 27370  ok, i might be a bit over confident in the tit...           13.0
# 28879                    vietnamese chicken with ginger.           11.0
# 29220  most recipes for white bean and chicken chilie...           11.0
# 29400  traditional maltese soup. cheese is supposed t...            NaN
#
#        description_length  name_word_count
# 4932                106.0                2
# 5200                110.0                4
# 8442                 50.0                4
# 9812                491.0                6
# 10978               471.0                2
# 11614               104.0                3
# 12124                32.0                3
# 12300                43.0                3
# 13294               250.0                5
# 13380                82.0                4
# 13397               203.0                8
# 14525               480.0                3
# 15938               302.0                4
# 17559               109.0                4
# 17803                89.0                5
# 20780                97.0                3
# 23035                81.0                4
# 23312                46.0                3
# 24477               261.0                6
# 26786                44.0                5
# 27370               801.0                8
# 28879                31.0                2
# 29220               178.0                5
# 29400               121.0                3

# %% [markdown]
# ### Объединение таблиц `pd.DataFrame`

# %% [markdown]
# 5.1 При помощи объединения таблиц, создайте `DataFrame`, состоящий из четырех столбцов: `id`, `name`, `user_id`, `rating`. Рецепты, на которые не оставлен ни один отзыв, должны отсутствовать в полученной таблице. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и попытавшись найти строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
new_df = pd.merge(recipes[["id","name"]], reviews[["user_id","rating","recipe_id"]], how='inner',left_on="id", right_on='recipe_id')
new_df = new_df.drop(labels="recipe_id",axis=1)
new_df.index.name='index'
new_df
# Out:
#             id                                    name  user_id  rating
# index
# 0        44123   George s at the cove  black bean soup   743566       5
# 1        44123   George s at the cove  black bean soup    76503       5
# 2        44123   George s at the cove  black bean soup    34206       5
# 3        67664      Healthy for them  yogurt popsicles   494084       5
# 4        67664      Healthy for them  yogurt popsicles   303445       5
# ...        ...                                     ...      ...     ...
# 126691  486161                             Zydeco soup   305531       5
# 126692  486161                             Zydeco soup  1271506       5
# 126693  486161                             Zydeco soup   724631       5
# 126694  486161                             Zydeco soup   133174       5
# 126695  298512  Cookies by design   cookies on a stick   804234       1
#
# [126696 rows x 4 columns]

# %%
reviews[reviews['review'].isna()].shape[0]
# Out:
# 17

# %%
reviews[reviews['review'].isna()].index
# Out:
# Int64Index([  56957,  273481,   56955,  783599, 1089381,  266359, 1078013,
#              841853, 1020267,   56966, 1096338,  633479,  270484,  303674,
#              510473,  774321,   26786],
#            dtype='int64', name='index')

# %%
reviews.loc[[56957]]
# Out:
#           user_id  recipe_id       date  rating review
# index
# 56957  2001567544       9054 2017-06-03       5    NaN

# %%
new_df.loc[[56957]]
# Out:
#           id                         name  user_id  rating
# index
# 56957  41231  Ham and provolone pinwheels    35193       5

# %%
print(reviews["review"].shape[0])
print(reviews["review"].dropna().shape[0])
print(new_df.shape[0])
# Out:
# 126696
# 126679
# 126696

# %% [markdown]
# 5.2 При помощи объединения таблиц и группировок, создайте `DataFrame`, состоящий из трех столбцов: `recipe_id`, `name`, `review_count`, где столбец `review_count` содержит кол-во отзывов, оставленных на рецепт `recipe_id`. У рецептов, на которые не оставлен ни один отзыв, в столбце `review_count` должен быть указан 0. Подтвердите правильность работы вашего кода, выбрав рецепт, не имеющий отзывов, и найдя строку, соответствующую этому рецепту, в полученном `DataFrame`.

# %%
test_indexes_df = recipes.merge(reviews, how='left', left_on="id", right_on="recipe_id").sort_values(by="user_id")
test_indexes_df[test_indexes_df['review'].isna() & test_indexes_df['rating'].isna()]["id"]
# Out:
# 191       223349
# 195       342620
# 216       276594
# 282       216068
# 300       306590
#            ...
# 128149     66966
# 128256    249846
# 128273    256177
# 128436    178243
# 128535    363362
# Name: id, Length: 1900, dtype: int64

# %%
other_new_df = recipes.merge(reviews['review'].groupby(reviews['recipe_id']).count(), how='left', left_on="id", right_on="recipe_id")[['id', 'name', 'review']]
other_new_df = other_new_df.rename(columns={'id': 'recipe_id', 'review': 'review_count'})
other_new_df = other_new_df.fillna(0)
other_new_df
# Out:
#        recipe_id                                          name  review_count
# 0          44123         George s at the cove  black bean soup           3.0
# 1          67664            Healthy for them  yogurt popsicles           8.0
# 2          38798                  I can t believe it s spinach           3.0
# 3          35173                          Italian  gut busters           1.0
# 4          84797      Love is in the air  beef fondue   sauces           8.0
# ...          ...                                           ...           ...
# 29995     267661  Zurie s holey rustic olive and cheddar bread           4.0
# 29996     386977          Zwetschgenkuchen  bavarian plum cake           2.0
# 29997     103312   Zwiebelkuchen   southwest german onion cake           6.0
# 29998     486161                                   Zydeco soup           6.0
# 29999     298512        Cookies by design   cookies on a stick           1.0
#
# [30000 rows x 3 columns]

# %%
other_new_df[other_new_df["recipe_id"] == 223349]
# Out:
#     recipe_id                           name  review_count
# 26     223349  Pasta  with shrimp   eggplant           0.0

# %% [markdown]
# 5.3. Выясните, рецепты, добавленные в каком году, имеют наименьший средний рейтинг?

# %%
reviews['rating'].groupby(pd.DatetimeIndex(reviews['date']).year).mean().sort_values()
# Out:
# date
# 2017    3.353042
# 2000    3.384615
# 2018    3.504076
# 2016    3.912603
# 2015    4.047145
# 2014    4.110595
# 2001    4.134426
# 2013    4.274168
# 2011    4.302045
# 2012    4.341427
# 2010    4.454440
# 2002    4.481556
# 2008    4.484635
# 2009    4.524728
# 2003    4.526940
# 2004    4.546548
# 2007    4.547077
# 2005    4.563680
# 2006    4.603673
# Name: rating, dtype: float64

# %% [markdown]
# ### Сохранение таблиц `pd.DataFrame`

# %% [markdown]
# 6.1 Отсортируйте таблицу в порядке убывания величины столбца `name_word_count` и сохраните результаты выполнения заданий 3.1-3.3 в csv файл.

# %%
recipes.sort_values(by=['name_word_count'])
recipes.to_csv("6.1.csv")
recipes
# Out:
#                                                name      id  minutes  \
# 0             George s at the cove  black bean soup   44123       90
# 1                Healthy for them  yogurt popsicles   67664       10
# 2                      I can t believe it s spinach   38798       30
# 3                              Italian  gut busters   35173       45
# 4          Love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  Zurie s holey rustic olive and cheddar bread  267661       80
# 29996          Zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   Zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   Zydeco soup  486161       60
# 29999        Cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# 2                1533 2002-08-29      NaN
# 3               22724 2002-07-27      NaN
# 4                4470 2004-02-23      4.0
# ...               ...        ...      ...
# 29995          200862 2007-11-25     16.0
# 29996          177443 2009-08-24      NaN
# 29997          161745 2004-11-03      NaN
# 29998          227978 2012-08-29      NaN
# 29999          506822 2008-04-15      9.0
#
#                                              description  n_ingredients  \
# 0      an original recipe created by chef scott meska...           18.0
# 1      my children and their friends ask for my homem...            NaN
# 2                these were so go, it surprised even me.            8.0
# 3      my sister-in-law made these for us at a family...            NaN
# 4      i think a fondue is a very romantic casual din...            NaN
# ...                                                  ...            ...
# 29995  this is based on a french recipe but i changed...           10.0
# 29996  this is a traditional fresh plum cake, thought...           11.0
# 29997  this is a traditional late summer early fall s...            NaN
# 29998  this is a delicious soup that i originally fou...            NaN
# 29999  i've heard of the 'cookies by design' company,...           10.0
#
#        description_length  name_word_count
# 0                   330.0                8
# 1                   255.0                5
# 2                    39.0                7
# 3                   154.0                3
# 4                   587.0                8
# ...                   ...              ...
# 29995               484.0                8
# 29996               286.0                4
# 29997               311.0                5
# 29998               648.0                2
# 29999               125.0                7
#
# [30000 rows x 10 columns]

# %% [markdown]
# 6.2 Воспользовавшись `pd.ExcelWriter`, cохраните результаты 5.1 и 5.2 в файл: на лист с названием `Рецепты с оценками` сохраните результаты выполнения 5.1; на лист с названием `Количество отзывов по рецептам` сохраните результаты выполнения 5.2.

# %%
with pd.ExcelWriter(r"6.2.xlsx") as writer:
    new_df.to_excel(writer, sheet_name="Рецепты с оценками")
    other_new_df.to_excel(writer, sheet_name="Количество отзывов по рецептам")
